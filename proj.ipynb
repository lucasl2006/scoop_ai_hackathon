# %%
import requests
import json

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=L5918IH11TGFFE2L'
r = requests.get(url)
data = r.json()

data = data["Time Series (Daily)"]
print(len(data)) 
#print(data)
bigList = []
returnList = []
data = str(data)

'''for i in range(100):
    one = data[1:].find('{')
    two = data.find('}')
    print(data[one:two+1])
    p1 = data[:one]
    print(p1)
    p2 = data[two-one:]
    print(p2)
    data = p1+p2'''
    

print(data)
